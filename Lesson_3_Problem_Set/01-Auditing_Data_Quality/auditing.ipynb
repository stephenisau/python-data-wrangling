# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
In this problem set you work with cities infobox data, audit it, come up with a
cleaning idea and then clean it up. In the first exercise we want you to audit
the datatypes that can be found in some particular fields in the dataset.
The possible types of values can be:
- NoneType if the value is a string "NULL" or an empty string ""
- list, if the value starts with "{"
- int, if the value can be cast to int
- float, if the value can be cast to float, but CANNOT be cast to int.
   For example, '3.23e+07' should be considered a float because it can be cast
   as float but int('3.23e+07') will throw a ValueError
- 'str', for all other values

The audit_file function should return a dictionary containing fieldnames and a 
SET of the types that can be found in the field. e.g.
{"field1": set([type(float()), type(int()), type(str())]),
 "field2": set([type(str())]),
  ....
}
The type() function returns a type object describing the argument given to the 
function. You can also use examples of objects to create type objects, e.g.
type(1.1) for a float: see the test function below for examples.

Note that the first three rows (after the header row) in the cities.csv file
are not actual data points. The contents of these rows should note be included
when processing data types. Be sure to include functionality in your code to
skip over or detect these rows.
"""

import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]


def isfloat(value):#create a function that tests whether a value can be cast as float
    try:
        float(value)
        return True
    except ValueError:
        return False
    
    
def isint(value):#create a function that determines if a value is an integer
    try:
        int(value)
        return True
    except ValueError:
        return False
    
def audit_file(filename, fields):
    fieldtypes = {}
    
    for field in fields:
        fieldtypes[field] = set()
    
    with open(filename, 'r') as f:
        reader = csv.DictReader(f)
        for line in reader:
            for field in fields:
                value = line[field]
                if value == 'NULL' or value == '':
                    fieldtypes[field].add(type(None))
                elif value.startswith('{'):
                    fieldtypes[field].add(type(list))
                else:
                    try:
                        fieldtypes[field].add(isint(value))
                    except ValueError:
                        try:
                            fieldtypes[field].add(isfloat(value))
                        except ValueError:
                            fieldtypes[field].add(str)
                        
                        

    return fieldtypes


def test():
    fieldtypes = audit_file(CITIES, FIELDS)

    pprint.pprint(fieldtypes)

    assert fieldtypes["areaLand"] == set([type(1.1), type([]), type(None)])
    assert fieldtypes['areaMetro'] == set([type(1.1), type(None)])
    
if __name__ == "__main__":
    test()
# Out:
# {'areaCode': {False, True, <class 'NoneType'>},
#  'areaLand': {False, <class 'NoneType'>, <class 'type'>},
#  'areaMetro': {False, <class 'NoneType'>},
#  'areaUrban': {False, <class 'NoneType'>},
#  'elevation': {False, <class 'NoneType'>, <class 'type'>},
#  'governmentType_label': {False, <class 'NoneType'>},
#  'homepage': {False, <class 'NoneType'>},
#  'isPartOf_label': {False, <class 'NoneType'>, <class 'type'>},
#  'maximumElevation': {False, <class 'NoneType'>},
#  'minimumElevation': {False, <class 'NoneType'>},
#  'name': {False, <class 'NoneType'>, <class 'type'>},
#  'populationDensity': {False, <class 'NoneType'>, <class 'type'>},
#  'populationTotal': {False, True, <class 'NoneType'>},
#  'timeZone_label': {False, <class 'NoneType'>},
#  'utcOffset': {False, True, <class 'NoneType'>, <class 'type'>},
#  'wgs84_pos#lat': {False},
#  'wgs84_pos#long': {False}}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-37ab0659eada> in <module>()
#      96
#      97 if __name__ == "__main__":
# ---> 98     test()
#
# <ipython-input-7-37ab0659eada> in test()
#      92     pprint.pprint(fieldtypes)
#      93
# ---> 94     assert fieldtypes["areaLand"] == set([type(1.1), type([]), type(None)])
#      95     assert fieldtypes['areaMetro'] == set([type(1.1), type(None)])
#      96
#
# AssertionError:

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]


def isfloat(value):#create a function that tests whether a value can be cast as float
    try:
        float(value)
        return True
    except ValueError:
        return False
    
    
def isint(value):#create a function that determines if a value is an integer
    try:
        int(value)
        return True
    except ValueError:
        return False

DATA = []

with open(CITIES, 'r') as f:
    reader = csv.DictReader(f)
    for i in range(3):
        next(reader)
    for line in reader:
        fieldValues = {}
        for field in FIELDS:
            fieldValues[field] = line[field]
            DATA.append(fieldValues)

# %%
DATA
# Out:
# [{'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
# ...
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'}]

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

short = ["name", "populationTotal", "areaMetro", "postalCode"]


DATA = []
fieldtypes = {}

for field in short:
    fieldtypes[field] = set()
    
with open(CITIES, 'r') as fin:
    reader = csv.DictReader(fin)
    for i in range(3):
        next(reader)
    for line in reader:
        for field in short:
            value = line[field]
            if value == 'NULL' or value == '':
                fieldtypes[field].add(type(None))
            elif value.startswith('{'):
                fieldtypes[field].add(list)
            else:
                try:
                    int(value)
                    fieldtypes[field].add(int)
                except ValueError:
                    try:
                        float(value)
                        fieldtypes[field].add(float)
                    except ValueError:
                        fieldtypes[field].add(str)
fieldtypes
# Out:
# {'name': {NoneType, list, str},
#  'populationTotal': {NoneType, int},
#  'areaMetro': {NoneType, float},
#  'postalCode': {NoneType, int, str}}

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

short = ["name", "populationTotal", "areaMetro", "postalCode"]


DATA = []
fieldtypes = {}

    
with open(CITIES, 'r') as fin:
    reader = csv.DictReader(fin)
    for i in range(3):
        next(reader)
    for line in reader:
        for field in short:
            value = line[field]
            #print(value)
            fieldtypes[field] = value
        #print(fieldtypes)
        DATA.append(fieldtypes)
DATA
# Out:
# [{'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'}]

# %%
DATA = []
fieldValues = {}
for field in FIELDS:
    fieldValues[field] = set()

with open(CITIES, 'r') as f:
    reader = csv.DictReader(f)
    for i in range(3):
        next(reader)
    for line in reader:
        fields = {}
        for field in FIELDS:
            value = line[field]
            fields[field] = value
        DATA.append(fields)
DATA
# Out:
# [{'name': 'Kud',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'areaCode': 'NULL',
#   'populationTotal': '1140',
#   'elevation': '1855.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kuju',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'areaCode': 'NULL',
#   'populationTotal': '18049',
#   'elevation': '426.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumbhraj',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'areaCode': 'NULL',
#   'populationTotal': '13999',
#   'elevation': '419.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kumhari',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'areaCode': 'NULL',
#   'populationTotal': '29737',
#   'elevation': '285.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kunigal',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'areaCode': '91-8132',
#   'populationTotal': '30291',
#   'elevation': '773.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kurgunta',
#   'timeZone_label': 'Indian Standard Time',
#   'utcOffset': '+5:30',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'areaCode': 'NULL',
#   'populationTotal': '8584',
#   'elevation': '418.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Athens',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alabama|Limestone County Alabama}',
#   'areaCode': '256 938',
#   'populationTotal': '21897',
#   'elevation': '{243.1|243.23}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '34.7897',
#   'wgs84_pos#long': '-86.9694',
#   'areaLand': '{1.01787e+08|1.019e+08}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Demopolis',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.demopolisal.gov',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alabama|Marengo County Alabama}',
#   'areaCode': '334',
#   'populationTotal': '7540',
#   'elevation': '{36.8808|37.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{233.4|234.789}',
#   'wgs84_pos#lat': '32.5094',
#   'wgs84_pos#long': '-87.8372',
#   'areaLand': '{3.15979e+07|3.17e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Chelsea Alabama',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.cityofchelsea.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alabama|Shelby County Alabama}',
#   'areaCode': '205',
#   'populationTotal': '10183',
#   'elevation': '{156.0|156.058}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{181.159|1215.3}',
#   'wgs84_pos#lat': '33.3292',
#   'wgs84_pos#long': '-86.6508',
#   'areaLand': '{5.51667e+07|5.53e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Pell City Alabama',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.epell.net/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alabama|St. Clair County Alabama}',
#   'areaCode': '205',
#   'populationTotal': '12463',
#   'elevation': '{181.966|182.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{176.912|177.3}',
#   'wgs84_pos#lat': '33.5708',
#   'wgs84_pos#long': '-86.2739',
#   'areaLand': '{6.36e+07|6.37137e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'City of Northport',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.cityofnorthport.org/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alabama|Tuscaloosa County Alabama}',
#   'areaCode': '205',
#   'populationTotal': '23442',
#   'elevation': '{67.0|67.056}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{504.8|507.029}',
#   'wgs84_pos#lat': '33.2539',
#   'wgs84_pos#long': '-87.5922',
#   'areaLand': '{3.78138e+07|3.79e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Sand Point',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'http://www.ci.sandpoint.ak.us/',
#   'governmentType_label': 'Mayor',
#   'isPartOf_label': '{Alaska|Aleutians East Borough Alaska}',
#   'areaCode': '907',
#   'populationTotal': '976',
#   'elevation': '{11.8872|12.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{47.1|47.1431}',
#   'wgs84_pos#lat': '55.3367',
#   'wgs84_pos#long': '-160.493',
#   'areaLand': '{2.02e+07|2.02019e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Unalaska Alaska',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alaska|Aleutians West Census Area Alaska}',
#   'areaCode': '907',
#   'populationTotal': '4376',
#   'elevation': '{3.9624|4.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '53.8889',
#   'wgs84_pos#long': '-166.527',
#   'areaLand': '{2.87489e+08|2.875e+08}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'City of Menlo Park',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'http://www.menlopark.org/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{California|San Mateo County California}',
#   'areaCode': '650',
#   'populationTotal': '32026',
#   'elevation': '{21.9456|22.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '37.4542',
#   'wgs84_pos#long': '-122.179',
#   'areaLand': '{2.5355e+07|2.5356e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': '{Negtemiut|Nightmute}',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alaska|Bethel Census Area Alaska}',
#   'areaCode': '907',
#   'populationTotal': '280',
#   'elevation': '{22.86|23.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '60.4914',
#   'wgs84_pos#long': '-164.826',
#   'areaLand': '{2.512e+08|2.51229e+08}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Fairbanks Alaska',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'NULL',
#   'governmentType_label': 'Home Rule in the United States',
#   'isPartOf_label': '{Alaska|Fairbanks North Star Borough Alaska}',
#   'areaCode': '907',
#   'populationTotal': '31535',
#   'elevation': '{135.941|136.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{379.114|379.7}',
#   'wgs84_pos#lat': '64.8436',
#   'wgs84_pos#long': '-147.723',
#   'areaLand': '{8.25e+07|8.26206e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Homer',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'http://www.ci.homer.ak.us/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alaska|Kenai Peninsula Borough Alaska}',
#   'areaCode': '907',
#   'populationTotal': '5003',
#   'elevation': '{28.956|29.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '59.6431',
#   'wgs84_pos#long': '-151.526',
#   'areaLand': '3.58195e+07',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Ketchikan Alaska',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alaska|Ketchikan Gateway Borough Alaska}',
#   'areaCode': '907',
#   'populationTotal': '8050',
#   'elevation': '0.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '714.1',
#   'wgs84_pos#lat': '55.35',
#   'wgs84_pos#long': '-131.673',
#   'areaLand': '1.13e+07',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': '{Nuniaq|Old Harbor}',
#   'timeZone_label': 'Alaska Time Zone',
#   'utcOffset': '{-8|-9}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Alaska|Kodiak Island Borough Alaska}',
#   'areaCode': '907',
#   'populationTotal': '218',
#   'elevation': '{0.9144|1.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '4.1',
#   'wgs84_pos#lat': '57.1972',
#   'wgs84_pos#long': '-153.308',
#   'areaLand': '5.32e+07',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Rainier Washington',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Thurston County Washington|Washington (state)}',
#   'areaCode': '360',
#   'populationTotal': '1794',
#   'elevation': '{131.978|132.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{400.388|400.4}',
#   'wgs84_pos#lat': '46.8908',
#   'wgs84_pos#long': '-122.69',
#   'areaLand': '{4.48e+06|4.48068e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'City of Blaine',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'http://www.cityofblaine.com/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Washington (state)|Whatcom County Washington}',
#   'areaCode': '360',
#   'populationTotal': '4684',
#   'elevation': '{16.0|16.1544}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{321.2|321.237}',
#   'wgs84_pos#lat': '48.9881',
#   'wgs84_pos#long': '-122.744',
#   'areaLand': '{1.458e+07|1.45816e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Ferndale Washington',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'http://www.ci.ferndale.wa.us/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Washington (state)|Whatcom County Washington}',
#   'areaCode': '360',
#   'populationTotal': '11415',
#   'elevation': '{10.9728|11.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{666.76|666.8}',
#   'wgs84_pos#lat': '48.8489',
#   'wgs84_pos#long': '-122.59',
#   'areaLand': '{1.71198e+07|1.712e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Mabton Washington',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Washington (state)|Yakima County Washington}',
#   'areaCode': '509',
#   'populationTotal': '2286',
#   'elevation': '{217.932|218.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{1103.29|1103.3}',
#   'wgs84_pos#lat': '46.2117',
#   'wgs84_pos#long': '-119.996',
#   'areaLand': '{2.07e+06|2.07199e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Zillah Washington',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'http://www.cityofzillah.us/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Washington (state)|Yakima County Washington}',
#   'areaCode': '509',
#   'populationTotal': '2964',
#   'elevation': '{249.936|250.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{642.9|642.937}',
#   'wgs84_pos#lat': '46.4036',
#   'wgs84_pos#long': '-120.261',
#   'areaLand': '{4.61e+06|4.61018e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Kenova West Virginia',
#   'timeZone_label': 'Eastern Time Zone',
#   'utcOffset': '{-4|-5}',
#   'homepage': 'http://www.cityofkenova.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Wayne County West Virginia|West Virginia}',
#   'areaCode': '304',
#   'populationTotal': '3216',
#   'elevation': '{170.0|170.078}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{985.487|985.5}',
#   'wgs84_pos#lat': '38.3997',
#   'wgs84_pos#long': '-82.5786',
#   'areaLand': '{3.26e+06|3.26339e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Fitchburg Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.city.fitchburg.wi.us/index.php',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Dane County Wisconsin|Wisconsin}',
#   'areaCode': '608',
#   'populationTotal': '25260',
#   'elevation': 'NULL',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{278.882|278.9}',
#   'wgs84_pos#lat': '43.0064',
#   'wgs84_pos#long': '-89.4314',
#   'areaLand': '{9.057e+07|9.05719e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stoughton Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.cityofstoughton.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Dane County Wisconsin|Wisconsin}',
#   'areaCode': '608',
#   'populationTotal': '12611',
#   'elevation': '{267.0|267.005}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{989.657|989.7}',
#   'wgs84_pos#lat': '42.9211',
#   'wgs84_pos#long': '-89.2244',
#   'areaLand': '{1.274e+07|1.27427e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Watertown Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Dodge County Wisconsin|Jefferson County Wisconsin|Wisconsin}',
#   'areaCode': '920',
#   'populationTotal': '23861',
#   'elevation': '{259.994|260.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{760.776|760.8}',
#   'wgs84_pos#lat': '43.2',
#   'wgs84_pos#long': '-88.7167',
#   'areaLand': '{3.136e+07|3.13648e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'LaCrosse Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.cityoflacrosse.org/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{La Crosse County Wisconsin|Wisconsin}',
#   'areaCode': '608',
#   'populationTotal': '51320',
#   'elevation': '{203.911|204.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{965.6|965.641}',
#   'wgs84_pos#lat': '43.8133',
#   'wgs84_pos#long': '-91.2331',
#   'areaLand': '{5.31466e+07|5.315e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Wauwatosa Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.wauwatosa.net',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Milwaukee County Wisconsin|Wisconsin}',
#   'areaCode': '414',
#   'populationTotal': '46396',
#   'elevation': '{205.0|205.13}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{1351.98|1352.0}',
#   'wgs84_pos#lat': '43.0589',
#   'wgs84_pos#long': '-88.0261',
#   'areaLand': '{3.43173e+07|3.432e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Osseo Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Trempealeau County Wisconsin|Wisconsin}',
#   'areaCode': '715 & 534',
#   'populationTotal': '1701',
#   'elevation': '{291.998|292.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{318.8|318.805}',
#   'wgs84_pos#lat': '44.5783',
#   'wgs84_pos#long': '-91.2183',
#   'areaLand': '{5.33538e+06|5.34e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Muskego Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.ci.muskego.wi.us/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Waukesha County Wisconsin|Wisconsin}',
#   'areaCode': '414 262',
#   'populationTotal': '24135',
#   'elevation': '{244.0|244.145}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{294.9|294.905}',
#   'wgs84_pos#lat': '42.9012',
#   'wgs84_pos#long': '-88.1246',
#   'areaLand': '{8.184e+07|8.18436e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Clintonville Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Waupaca County Wisconsin|Wisconsin}',
#   'areaCode': '715 & 534',
#   'populationTotal': '4559',
#   'elevation': '{248.0|248.107}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{400.0|400.04}',
#   'wgs84_pos#lat': '44.6242',
#   'wgs84_pos#long': '-88.7581',
#   'areaLand': '{1.13959e+07|1.14e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Hartford Wisconsin',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Dodge County Wisconsin|Washington County Wisconsin|Wisconsin}',
#   'areaCode': '262',
#   'populationTotal': '14223',
#   'elevation': '{299.0|299.009}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{691.6|691.625}',
#   'wgs84_pos#lat': '43.3183',
#   'wgs84_pos#long': '-88.3789',
#   'areaLand': '{2.056e+07|2.05645e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'City of Spokane Valley Washington',
#   'timeZone_label': 'Pacific Time Zone',
#   'utcOffset': '{-7|-8}',
#   'homepage': 'http://www.spokanevalley.org/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Spokane County Washington|Washington (state)}',
#   'areaCode': '509',
#   'populationTotal': '89755',
#   'elevation': 'NULL',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{917.5|917.533}',
#   'wgs84_pos#lat': '47.6733',
#   'wgs84_pos#long': '-117.239',
#   'areaLand': '{9.782e+07|9.78239e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'NULL',
#   'timeZone_label': 'Time in China',
#   'utcOffset': '+8',
#   'homepage': 'http://www.harbin.gov.cn/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': 'Heilongjiang',
#   'areaCode': '451',
#   'populationTotal': '10635971',
#   'elevation': '{148.742|150.0}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '45.75',
#   'wgs84_pos#long': '126.633',
#   'areaLand': 'NULL',
#   'areaMetro': '7.068e+09',
#   'areaUrban': '7.068e+09'},
#  {'name': 'Dortmund',
#   'timeZone_label': 'NULL',
#   'utcOffset': 'NULL',
#   'homepage': 'http://www.dortmund.de/',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': 'NULL',
#   'areaCode': '0231 02304',
#   'populationTotal': 'NULL',
#   'elevation': '86.0',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': 'NULL',
#   'wgs84_pos#lat': '51.5167',
#   'wgs84_pos#long': '7.46667',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Stratford Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'http://www.stratfordiowa.com',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'areaCode': '515',
#   'populationTotal': '743',
#   'elevation': '{338.0|338.023}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'}]

# %% [markdown]
# Everythiing below this is notes to test out code

# %%
DATA[0:5]
# Out:
# [{'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'},
#  {'name': 'Forest City Iowa',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'utcOffset': '{-5|-6}',
#   'homepage': 'NULL',
#   'governmentType_label': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'areaCode': '641',
#   'populationTotal': '4151',
#   'elevation': '{383.0|383.134}',
#   'maximumElevation': 'NULL',
#   'minimumElevation': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaUrban': 'NULL'}]

# %%
fieldtypes = {}
for i in FIELDS:
    fieldtypes[i] = set()
print(fieldtypes)
# Out:
# {'name': set(), 'timeZone_label': set(), 'utcOffset': set(), 'homepage': set(), 'governmentType_label': set(), 'isPartOf_label': set(), 'areaCode': set(), 'populationTotal': set(), 'elevation': set(), 'maximumElevation': set(), 'minimumElevation': set(), 'populationDensity': set(), 'wgs84_pos#lat': set(), 'wgs84_pos#long': set(), 'areaLand': set(), 'areaMetro': set(), 'areaUrban': set()}

# %%
DATA = []
fieldtypes = {}
for i in FIELDS:
    fieldtypes[i] = set()
    
with open(CITIES, 'r') as f:
    reader = csv.DictReader(f)
    for i in range(3):
        next(reader)
    for line in reader:
        for field in FIELDS:
            value = line[field]
            if value == 'NULL' or value == '':
                fieldtypes[field].add(type(None))
            elif value.startswith('{'):
                fieldtypes[field].add(list)
            else:
                try:
                    int(value)
                    fieldtypes[field].add(int)
                except ValueError:
                    try:
                        float(value)
                        fieldtypes[field].add(float)
                    except ValueError:
                        fieldtypes[field].add(str)
fieldtypes
# Out:
# {'name': {NoneType, list, str},
#  'timeZone_label': {NoneType, str},
#  'utcOffset': {NoneType, int, list, str},
#  'homepage': {NoneType, str},
#  'governmentType_label': {NoneType, str},
#  'isPartOf_label': {NoneType, list, str},
#  'areaCode': {NoneType, int, str},
#  'populationTotal': {NoneType, int},
#  'elevation': {NoneType, float, list},
#  'maximumElevation': {NoneType},
#  'minimumElevation': {NoneType},
#  'populationDensity': {NoneType, float, list},
#  'wgs84_pos#lat': {float},
#  'wgs84_pos#long': {float},
#  'areaLand': {NoneType, float, list},
#  'areaMetro': {NoneType, float},
#  'areaUrban': {NoneType, float}}

# %%
print(fieldtypes)
# Out:
# {'name': {'NULL'}, 'timeZone_label': {'NULL'}, 'utcOffset': {'NULL'}, 'homepage': {'NULL'}, 'governmentType_label': {'NULL'}, 'isPartOf_label': {'NULL'}, 'areaCode': {'NULL'}, 'populationTotal': {'NULL'}, 'elevation': {'NULL'}, 'maximumElevation': {'NULL'}, 'minimumElevation': {'NULL'}, 'populationDensity': {'NULL'}, 'wgs84_pos#lat': set(), 'wgs84_pos#long': set(), 'areaLand': {'NULL'}, 'areaMetro': {'NULL'}, 'areaUrban': {'NULL'}}

# %%
def audit_file(filename, fields):
    fieldtypes = {}
    for i in FIELDS:
        fieldtypes[i] = []
    with open(filename,'r') as f:
        reader = csv.DictReader(f)
        header = reader.fieldnames
        for field in FIELDS:
            for row in reader:
                if row[field] == "NULL" or row[field] == "":
                    fieldtypes[field].append(type(None))
                elif row[field[0]] == '{':
                    fieldtypes[field].append(type([]))
                elif isint(row[field]):
                    fieldtypes[field].append(type(1.1))

# %%
with open(CITIES, "r") as f:
    reader = csv.DictReader(f)
    header = reader.fieldnames
    for field in FIELDS:
        for row in reader:
            if row[field] == "NULL" or row[field] == "":
                fieldtypes[field].append(type(None))
# Out:
# ['URI', 'rdf-schema#label', 'rdf-schema#comment', 'administrativeDistrict_label', 'administrativeDistrict', 'anthem_label', 'anthem', 'area', 'areaCode', 'areaLand', 'areaMetro', 'areaRural', 'areaTotal', 'areaUrban', 'areaWater', 'city_label', 'city', 'code', 'country_label', 'country', 'daylightSavingTimeZone_label', 'daylightSavingTimeZone', 'district_label', 'district', 'division_label', 'division', 'elevation', 'federalState_label', 'federalState', 'foundingDate', 'foundingPerson_label', 'foundingPerson', 'foundingYear', 'governingBody_label', 'governingBody', 'government_label', 'government', 'governmentType_label', 'governmentType', 'isPartOf_label', 'isPartOf', 'isoCodeRegion_label', 'isoCodeRegion', 'leader_label', 'leader', 'leaderName_label', 'leaderName', 'leaderParty_label', 'leaderParty', 'leaderTitle', 'location_label', 'location', 'maximumElevation', 'mayor_label', 'mayor', 'minimumElevation', 'motto', 'municipality_label', 'municipality', 'part_label', 'part', 'percentageOfAreaWater', 'populationAsOf', 'populationDensity', 'populationMetro', 'populationMetroDensity', 'populationRural', 'populationTotal', 'populationTotalRanking', 'populationUrban', 'populationUrbanDensity', 'postalCode', 'region_label', 'region', 'state_label', 'state', 'synonym', 'thumbnail_label', 'thumbnail', 'timeZone_label', 'timeZone', 'twinCity_label', 'twinCity', 'twinCountry_label', 'twinCountry', 'type_label', 'type', 'utcOffset', 'point', '22-rdf-syntax-ns#type_label', '22-rdf-syntax-ns#type', 'wgs84_pos#lat', 'wgs84_pos#long', 'depiction_label', 'depiction', 'homepage_label', 'homepage', 'name', 'nick']

# %%
fieldtypes = {}
for i in FIELDS:
    fieldtypes[i] = []
with open(CITIES,'r') as f:
    reader = csv.DictReader(f)
    header = reader.fieldnames
    for field in FIELDS:
        for row in reader:
            if row[field] == "NULL" or row[field] == "":
                fieldtypes[field].append(type(None))
            elif row[field][0] == '{':
                fieldtypes[field].append(type([]))
            elif isint(row[field]):
                    fieldtypes[field].append(type(1.1))
        f.seek(0)
for i in fieldtypes:
    fieldtypes[i] = set(fieldtypes[i])
print(fieldtypes)
# Out:
# {'name': {<class 'NoneType'>, <class 'list'>}, 'timeZone_label': {<class 'NoneType'>}, 'utcOffset': {<class 'float'>, <class 'NoneType'>, <class 'list'>}, 'homepage': {<class 'NoneType'>}, 'governmentType_label': {<class 'NoneType'>}, 'isPartOf_label': {<class 'NoneType'>, <class 'list'>}, 'areaCode': {<class 'NoneType'>, <class 'float'>}, 'populationTotal': {<class 'NoneType'>, <class 'float'>}, 'elevation': {<class 'NoneType'>, <class 'list'>}, 'maximumElevation': {<class 'NoneType'>}, 'minimumElevation': {<class 'NoneType'>}, 'populationDensity': {<class 'NoneType'>, <class 'list'>}, 'wgs84_pos#lat': set(), 'wgs84_pos#long': set(), 'areaLand': {<class 'NoneType'>, <class 'list'>}, 'areaMetro': {<class 'NoneType'>}, 'areaUrban': {<class 'NoneType'>}}

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

fields = ["name", "populationTotal", "areaMetro", "postalCode"]


DATA = []
VALUES = {}
for i in fields:
    VALUES[i] = 0

    
VALUES
# Out:
# {'name': 0, 'populationTotal': 0, 'areaMetro': 0, 'postalCode': 0}

# %%
DATA = []
with open(CITIES, 'r') as f:
    reader = csv.DictReader(f)
    for i in range(3):
        next(reader)
    for line in reader:
        VALUES = {}
        for field in fields:
            VALUES[field] = line[field]
            
        DATA.append(VALUES)
for i in DATA:
    print(i['name'])
    #print(i['populationTotal'])
    #print(i['areaMetro'])
print(DATA['name'][12])
# Out:
# Kud
# Kuju
# Kumbhraj
# Kumhari
# Kunigal
# Kurgunta
# Athens
# Demopolis
# Chelsea Alabama
# Pell City Alabama
# City of Northport
# Sand Point
# Unalaska Alaska
# City of Menlo Park
# {Negtemiut|Nightmute}
# Fairbanks Alaska
# Homer
# Ketchikan Alaska
# {Nuniaq|Old Harbor}
# Rainier Washington
# City of Blaine
# Ferndale Washington
# Mabton Washington
# Zillah Washington
# Kenova West Virginia
# Fitchburg Wisconsin
# Stoughton Wisconsin
# Watertown Wisconsin
# LaCrosse Wisconsin
# Wauwatosa Wisconsin
# Osseo Wisconsin
# Muskego Wisconsin
# Clintonville Wisconsin
# Hartford Wisconsin
# City of Spokane Valley Washington
# NULL
# Dortmund
# Stratford Iowa
# Forest City Iowa
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-a990977a2128> in <module>()
#      14     #print(i['populationTotal'])
#      15     #print(i['areaMetro'])
# ---> 16 print(DATA['name'][12])
#
# TypeError: list indices must be integers or slices, not str

# %%
name = ''
print(not name)
# Out:
# True

# %%
DATA
# Out:
# [{'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'},
#  {'name': 'Forest City Iowa',
#   'populationTotal': '4151',
#   'areaMetro': 'NULL',
#   'postalCode': '50436'}]

# %%
import codecs
import csv
import json
import pprint

CITIES = 'cities.csv'

FIELDS = ["name", "timeZone_label", "utcOffset", "homepage", "governmentType_label",
          "isPartOf_label", "areaCode", "populationTotal", "elevation",
          "maximumElevation", "minimumElevation", "populationDensity",
          "wgs84_pos#lat", "wgs84_pos#long", "areaLand", "areaMetro", "areaUrban"]

def opendata(filename):
    DATA = []
    with open(filename, 'r') as f:
        reader = csv.DictReader(f)
        header = reader.fieldnames
        for i in range(3):
            next(reader)
        for line in reader:
            fieldValues = {}
            for field in header:
                value = line[field]
                fieldValues[field] = value
                #print(fieldValues)
            DATA.append(fieldValues)
            
        return DATA

# %%
a = opendata(CITIES)
a
# Out:
# [{'URI': 'http://dbpedia.org/resource/Kud',
#   'rdf-schema#label': 'Kud',
#   'rdf-schema#comment': 'Kud is a town and a notified area committee in Udhampur District in the Indian state of Jammu and Kashmir.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': 'NULL',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '1855.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Jammu and Kashmir|Udhampur district}',
#   'isPartOf': '{http://dbpedia.org/resource/Jammu_and_Kashmir|http://dbpedia.org/resource/Udhampur_district}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '1140',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': 'NULL',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '33.08 75.28',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '33.08',
#   'wgs84_pos#long': '75.28',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kud',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Kuju,_Hazaribag',
#   'rdf-schema#label': 'Kuju Hazaribag',
#   'rdf-schema#comment': 'Kuju is a census town in Ramgarh district in the Indian state of Jharkhand.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': 'NULL',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '426.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Jharkhand|Ramgarh district}',
#   'isPartOf': '{http://dbpedia.org/resource/Jharkhand|http://dbpedia.org/resource/Ramgarh_district}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '18049',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': 'NULL',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '23.72 85.5',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '23.72',
#   'wgs84_pos#long': '85.5',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kuju',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Kumbhraj',
#   'rdf-schema#label': 'Kumbhraj',
#   'rdf-schema#comment': 'Kumbhraj is a town and a nagar panchayat in Guna district in the Indian state of Madhya Pradesh.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': 'NULL',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '419.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Guna district|Madhya Pradesh}',
#   'isPartOf': '{http://dbpedia.org/resource/Guna_district|http://dbpedia.org/resource/Madhya_Pradesh}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '13999',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': 'NULL',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '24.37 77.05',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '24.37',
#   'wgs84_pos#long': '77.05',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kumbhraj',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Kumhari',
#   'rdf-schema#label': 'Kumhari',
#   'rdf-schema#comment': 'Kumhari is a town and a nagar panchayat in Durg district in the Indian state of Chhattisgarh.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': 'NULL',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '285.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Chhattisgarh|Durg district}',
#   'isPartOf': '{http://dbpedia.org/resource/Chhattisgarh|http://dbpedia.org/resource/Durg_district}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '29737',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': 'NULL',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '21.27 81.52',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '21.27',
#   'wgs84_pos#long': '81.52',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kumhari',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Kunigal',
#   'rdf-schema#label': 'Kunigal',
#   'rdf-schema#comment': 'Kunigal is a town in Tumkur district in the Indian state of Karnataka. It is the headquarters of Kunigal taluk. Kunigal is famous for stud farm owned by Vijay Mallya.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '91-8132',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '773.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Karnataka|Tumkur district}',
#   'isPartOf': '{http://dbpedia.org/resource/Karnataka|http://dbpedia.org/resource/Tumkur_district}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '30291',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '572130',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '13.02 77.03',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '13.02',
#   'wgs84_pos#long': '77.03',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kunigal',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Kurgunta',
#   'rdf-schema#label': 'Kurgunta',
#   'rdf-schema#comment': 'Kurgunta is a census town in Gulbarga district in the Indian state of Karnataka.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': 'NULL',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': 'NULL',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'India',
#   'country': 'http://dbpedia.org/resource/India',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '418.0',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Gulbarga district|Karnataka}',
#   'isPartOf': '{http://dbpedia.org/resource/Gulbarga_district|http://dbpedia.org/resource/Karnataka}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '8584',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': 'NULL',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': 'NULL',
#   'thumbnail': 'NULL',
#   'timeZone_label': 'Indian Standard Time',
#   'timeZone': 'http://dbpedia.org/resource/Indian_Standard_Time',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '+5:30',
#   'point': '17.2 77.35',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '17.2',
#   'wgs84_pos#long': '77.35',
#   'depiction_label': 'NULL',
#   'depiction': 'NULL',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Kurgunta',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Athens,_Alabama',
#   'rdf-schema#label': 'Athens Alabama',
#   'rdf-schema#comment': 'Athens is a city in Limestone County Alabama United States. As of the 2010 census the population of the city is 21897. The city is the county seat of Limestone County and is included in the Huntsville-Decatur Combined Statistical Area.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': '1.0',
#   'areaCode': '256 938',
#   'areaLand': '{1.01787e+08|1.019e+08}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{1.02046e+08|1.021e+08}',
#   'areaUrban': 'NULL',
#   'areaWater': '{200000.0|258999.0}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{243.1|243.23}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': '1818-11-19',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alabama|Limestone County Alabama}',
#   'isPartOf': '{http://dbpedia.org/resource/Alabama|http://dbpedia.org/resource/Limestone_County,_Alabama}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': '{City Council|Mayor}',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '21897',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '35611-35614-35613',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Limestone_County_Courthouse_Athens_Alabama_01.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Limestone_County_Courthouse,_Athens,_Alabama_01.jpg/200px-Limestone_County_Courthouse,_Athens,_Alabama_01.jpg',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '34.789722222222224 -86.96944444444445',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '34.7897',
#   'wgs84_pos#long': '-86.9694',
#   'depiction_label': 'Limestone_County_Courthouse_Athens_Alabama_01.jpg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/5/5a/Limestone_County_Courthouse,_Athens,_Alabama_01.jpg',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Athens',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Demopolis,_Alabama',
#   'rdf-schema#label': 'Demopolis Alabama',
#   'rdf-schema#comment': "Demopolis is the largest city in Marengo County Alabama United States. The population was 7483 at the time of the 2010 United States Census. The city lies within Webb's Bend at the confluence of the Black Warrior and Tombigbee rivers. It is situated atop a cliff composed of the Demopolis Chalk Formation known locally as White Bluff on the east bank of the Tombigbee River. It is at the center of Alabama's Canebrake region and is also within the Black Belt.",
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '334',
#   'areaLand': '{3.15979e+07|3.17e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{3.21159e+07|3.23e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '{517998.0|600000.0}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'NULL',
#   'country': 'NULL',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{36.8808|37.0}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alabama|Marengo County Alabama}',
#   'isPartOf': '{http://dbpedia.org/resource/Alabama|http://dbpedia.org/resource/Marengo_County,_Alabama}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{233.4|234.789}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '7540',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '36732',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Demopolis_Alabama_with_river_confluence.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/5/5e/Demopolis_Alabama_with_river_confluence.jpg/200px-Demopolis_Alabama_with_river_confluence.jpg',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': '{-5|-6}',
#   'point': '32.50944444444445 -87.83722222222222',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '32.5094',
#   'wgs84_pos#long': '-87.8372',
#   'depiction_label': 'Demopolis_Alabama_with_river_confluence.jpg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/5/5e/Demopolis_Alabama_with_river_confluence.jpg',
#   'homepage_label': 'www.demopolisal.gov',
#   'homepage': 'http://www.demopolisal.gov',
#   'name': 'Demopolis',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Chelsea,_Alabama',
#   'rdf-schema#label': 'Chelsea Alabama',
#   'rdf-schema#comment': 'Chelsea is a city in Shelby County Alabama United States. Chelsea was incorporated on March 1 1996 with a population of 906. At the 2000 census the population was 2949. According to U.S. Census Bureau the 2010 population for Chelsea was 10183. Chelsea is widely considered the fastest growing city in Shelby County which is the fastest growing county in the state of Alabama.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '205',
#   'areaLand': '{5.51667e+07|5.53e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{5.62e+07|5.62027e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '{776996.0|900000.0}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{156.0|156.058}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alabama|Shelby County Alabama}',
#   'isPartOf': '{http://dbpedia.org/resource/Alabama|http://dbpedia.org/resource/Shelby_County,_Alabama}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': "It's all about family",
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{181.159|1215.3}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '10183',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '35043',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Chelsea_Alabama.JPG',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/4/49/Chelsea,_Alabama.JPG/200px-Chelsea,_Alabama.JPG',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '33.329166666666666 -86.65083333333334',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '33.3292',
#   'wgs84_pos#long': '-86.6508',
#   'depiction_label': 'Chelsea_Alabama.JPG',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/4/49/Chelsea,_Alabama.JPG',
#   'homepage_label': 'www.cityofchelsea.com',
#   'homepage': 'http://www.cityofchelsea.com',
#   'name': 'Chelsea Alabama',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Pell_City,_Alabama',
#   'rdf-schema#label': 'Pell City Alabama',
#   'rdf-schema#comment': 'Pell City is a city in St. Clair County Alabama United States. The city is the county seat of St. Clair County along with Ashville. At the 2000 census the population was 9565. At the 2010 census the city-limit population jumped to 12695.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '205',
#   'areaLand': '{6.36e+07|6.37137e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{7.03e+07|7.04477e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '{6.7e+06|6.73397e+06}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{181.966|182.0}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alabama|St. Clair County Alabama}',
#   'isPartOf': '{http://dbpedia.org/resource/Alabama|http://dbpedia.org/resource/St._Clair_County,_Alabama}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{176.912|177.3}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '12463',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '35125 35128 35054',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-St._Clair_County_Alabama_Incorporated_and_Unincorporated_areas_Pell_City_Highlighted.svg.png',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/e/eb/St._Clair_County_Alabama_Incorporated_and_Unincorporated_areas_Pell_City_Highlighted.svg/200px-St._Clair_County_Alabama_Incorporated_and_Unincorporated_areas_Pell_City_Highlighted.svg.png',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '33.57083333333333 -86.27388888888889',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '33.5708',
#   'wgs84_pos#long': '-86.2739',
#   'depiction_label': 'St._Clair_County_Alabama_Incorporated_and_Unincorporated_areas_Pell_City_Highlighted.svg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/e/eb/St._Clair_County_Alabama_Incorporated_and_Unincorporated_areas_Pell_City_Highlighted.svg',
#   'homepage_label': '',
#   'homepage': 'http://www.epell.net/',
#   'name': 'Pell City Alabama',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Northport,_Alabama',
#   'rdf-schema#label': 'Northport Alabama',
#   'rdf-schema#comment': 'Northport is a city in Tuscaloosa County in the west central part of the U.S. state of Alabama. Located on the Black Warrior River across from downtown Tuscaloosa it is currently the 24th largest city in Alabama with an estimated population of 23442 in 2009. It is part of the Tuscaloosa Metropolitan Statistical Area.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '205',
#   'areaLand': '{3.78138e+07|3.79e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{3.83318e+07|3.85e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '{517998.0|600000.0}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{67.0|67.056}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alabama|Tuscaloosa County Alabama}',
#   'isPartOf': '{http://dbpedia.org/resource/Alabama|http://dbpedia.org/resource/Tuscaloosa_County,_Alabama}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'Mayor',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{504.8|507.029}',
#   'populationMetro': '210839',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '23442',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '35473 35475 35476',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Downtown-Northport-Alabama.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/a/ab/Downtown-Northport-Alabama.jpg/200px-Downtown-Northport-Alabama.jpg',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '33.25388888888889 -87.59222222222222',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '33.2539',
#   'wgs84_pos#long': '-87.5922',
#   'depiction_label': 'Downtown-Northport-Alabama.jpg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/a/ab/Downtown-Northport-Alabama.jpg',
#   'homepage_label': '',
#   'homepage': 'http://www.cityofnorthport.org/',
#   'name': 'City of Northport',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Sand_Point,_Alaska',
#   'rdf-schema#label': 'Sand Point Alaska',
#   'rdf-schema#comment': 'Sand Point also known as Qagun Tayagungin is a city in Aleutians East Borough Alaska United States. At the 2010 census the population was 976. It is located on northwestern Popof Island one of the Shumagin Islands off the Alaska Peninsula. It is the borough seat of Aleutians East Borough and is located near the entrance to the Bering Sea.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '907',
#   'areaLand': '{2.02e+07|2.02019e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{7.48507e+07|7.5e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '{5.46487e+07|5.48e+07}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'NULL',
#   'country': 'NULL',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{11.8872|12.0}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'Mayor',
#   'governmentType': 'http://dbpedia.org/resource/Mayor',
#   'isPartOf_label': '{Alaska|Aleutians East Borough Alaska}',
#   'isPartOf': '{http://dbpedia.org/resource/Alaska|http://dbpedia.org/resource/Aleutians_East_Borough,_Alaska}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'Mayor',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{47.1|47.1431}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '976',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '99661',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-SDP_Aerial_2.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/0/01/SDP_Aerial_2.jpg/200px-SDP_Aerial_2.jpg',
#   'timeZone_label': 'Alaska Time Zone',
#   'timeZone': 'http://dbpedia.org/resource/Alaska_Time_Zone',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'Alaska',
#   'type': 'http://dbpedia.org/resource/Alaska',
#   'utcOffset': '{-8|-9}',
#   'point': '55.336666666666666 -160.49333333333334',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '55.3367',
#   'wgs84_pos#long': '-160.493',
#   'depiction_label': 'SDP_Aerial_2.jpg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/0/01/SDP_Aerial_2.jpg',
#   'homepage_label': '',
#   'homepage': 'http://www.ci.sandpoint.ak.us/',
#   'name': 'Sand Point',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Unalaska,_Alaska',
#   'rdf-schema#label': 'Unalaska Alaska',
#   'rdf-schema#comment': "Unalaska is a city in the Aleutians West Census Area of the Unorganized Borough of the U.S. state of Alaska. Unalaska is located on Unalaska Island and neighboring Amaknak Island in the Aleutian Islands off mainland Alaska. The population was 4376 at the 2010 census which is 79% of the entire Aleutians West Census Area. Almost all of the community's port facilities are on Amaknak Island better known as Dutch Harbor or just Dutch. It is the largest fisheries port in the U.S.",
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '907',
#   'areaLand': '{2.87489e+08|2.875e+08}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{5.49854e+08|5.499e+08}',
#   'areaUrban': 'NULL',
#   'areaWater': '{2.62366e+08|2.624e+08}',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{3.9624|4.0}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Alaska|Aleutians West Census Area Alaska}',
#   'isPartOf': '{http://dbpedia.org/resource/Alaska|http://dbpedia.org/resource/Aleutians_West_Census_Area,_Alaska}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'Mayor',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '4376',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '99685',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-UnalaskaAlaska.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/2/2e/UnalaskaAlaska.jpg/200px-UnalaskaAlaska.jpg',
#   'timeZone_label': 'Alaska Time Zone',
#   'timeZone': 'http://dbpedia.org/resource/Alaska_Time_Zone',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'Alaska',
#   'type': 'http://dbpedia.org/resource/Alaska',
#   'utcOffset': '{-8|-9}',
#   'point': '53.888888888888886 -166.52722222222224',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '53.8889',
#   'wgs84_pos#long': '-166.527',
#   'depiction_label': 'UnalaskaAlaska.jpg',
# ...
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '451',
#   'areaLand': 'NULL',
#   'areaMetro': '7.068e+09',
#   'areaRural': 'NULL',
#   'areaTotal': '5.31e+10',
#   'areaUrban': '7.068e+09',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'China',
#   'country': 'http://dbpedia.org/resource/China',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{148.742|150.0}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': 'Heilongjiang',
#   'isPartOf': 'http://dbpedia.org/resource/Heilongjiang',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': '{Lin_Duo|Song_Xibin}',
#   'leaderName': '{http://dbpedia.org/resource/Lin_Duo|http://dbpedia.org/resource/Song_Xibin}',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': '{Mayor|secretary of a municipal committee of the CPC}',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': 'NULL',
#   'populationMetro': '5878939',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '10635971',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': '5282083',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '150000',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Harbin_montage.png',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Harbin_montage.png/200px-Harbin_montage.png',
#   'timeZone_label': 'Time in China',
#   'timeZone': 'http://dbpedia.org/resource/Time_in_China',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': "Sub-provincial divisions in the People's Republic of China",
#   'type': "http://dbpedia.org/resource/Sub-provincial_divisions_in_the_People's_Republic_of_China",
#   'utcOffset': '+8',
#   'point': '45.75 126.63333333333334',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '45.75',
#   'wgs84_pos#long': '126.633',
#   'depiction_label': 'Harbin_montage.png',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/f/f3/Harbin_montage.png',
#   'homepage_label': '',
#   'homepage': 'http://www.harbin.gov.cn/',
#   'name': 'NULL',
#   'nick': 'Ice City Oriental Paris Oriental Moscow'},
#  {'URI': 'http://dbpedia.org/resource/Dortmund',
#   'rdf-schema#label': 'Dortmund',
#   'rdf-schema#comment': 'Dortmund is a city in Germany. It is located in the Bundesland of North Rhine-Westphalia. Its population of 579012 (in December 2012) makes it the 8th largest city in Germany. Dortmund is the largest city in the Ruhr Area an urban area with some 5.2 million (2009) inhabitants which is the largest urban agglomeration in Germany. Dortmund is also a part of the larger Rhine-Ruhr metropolitan region of more than 12 million people.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '0231 02304',
#   'areaLand': 'NULL',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '2.804e+08',
#   'areaUrban': 'NULL',
#   'areaWater': 'NULL',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'Germany',
#   'country': 'http://dbpedia.org/resource/Germany',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '86.0',
#   'federalState_label': 'North Rhine-Westphalia',
#   'federalState': 'http://dbpedia.org/resource/North_Rhine-Westphalia',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': 'NULL',
#   'isPartOf': 'NULL',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'Lord Mayor',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'NULL',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': '2010-12-31',
#   'populationDensity': 'NULL',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': 'NULL',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '44001-44388',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Dortmund.jpg',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Dortmund.jpg/200px-Dortmund.jpg',
#   'timeZone_label': 'NULL',
#   'timeZone': 'NULL',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'NULL',
#   'type': 'NULL',
#   'utcOffset': 'NULL',
#   'point': '51.516666666666666 7.466666666666667',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '51.5167',
#   'wgs84_pos#long': '7.46667',
#   'depiction_label': 'Dortmund.jpg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/2/2c/Dortmund.jpg',
#   'homepage_label': '',
#   'homepage': 'http://www.dortmund.de/',
#   'name': 'Dortmund',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Stratford,_Iowa',
#   'rdf-schema#label': 'Stratford Iowa',
#   'rdf-schema#comment': 'Stratford is a city in Hamilton and Webster counties in the U.S. state of Iowa. The population was 743 at the 2010 census.',
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '515',
#   'areaLand': '{4.94688e+06|4.95e+06}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{4.94688e+06|4.95e+06}',
#   'areaUrban': 'NULL',
#   'areaWater': '0.0',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{338.0|338.023}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': 'NULL',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Hamilton County Iowa|Iowa|Webster County Iowa}',
#   'isPartOf': '{http://dbpedia.org/resource/Hamilton_County,_Iowa|http://dbpedia.org/resource/Iowa|http://dbpedia.org/resource/Webster_County,_Iowa}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': 'The place to be',
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{150.194|150.2}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '743',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '50249',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Stratford_Iowa_20090419_Sign.JPG',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/8/89/Stratford_Iowa_20090419_Sign.JPG/200px-Stratford_Iowa_20090419_Sign.JPG',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '42.270833333333336 -93.92694444444444',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '42.2708',
#   'wgs84_pos#long': '-93.9269',
#   'depiction_label': 'Stratford_Iowa_20090419_Sign.JPG',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/8/89/Stratford_Iowa_20090419_Sign.JPG',
#   'homepage_label': 'www.stratfordiowa.com',
#   'homepage': 'http://www.stratfordiowa.com',
#   'name': 'Stratford Iowa',
#   'nick': 'NULL'},
#  {'URI': 'http://dbpedia.org/resource/Forest_City,_Iowa',
#   'rdf-schema#label': 'Forest City Iowa',
#   'rdf-schema#comment': "Forest City is a city in Hancock and Winnebago Counties in the U.S. state of Iowa and the county seat of Winnebago County. The population was 4151 in the 2010 census a decline from the 4362 population in the 2000 census. Forest City claims to be the smallest city in the United States with its own YMCA thanks to the benevolence of John K. and Luise V. Hanson. In reality it's not even the smallest city in Iowa with its own YMCA.",
#   'administrativeDistrict_label': 'NULL',
#   'administrativeDistrict': 'NULL',
#   'anthem_label': 'NULL',
#   'anthem': 'NULL',
#   'area': 'NULL',
#   'areaCode': '641',
#   'areaLand': '{1.20175e+07|1.202e+07}',
#   'areaMetro': 'NULL',
#   'areaRural': 'NULL',
#   'areaTotal': '{1.20175e+07|1.202e+07}',
#   'areaUrban': 'NULL',
#   'areaWater': '0.0',
#   'city_label': 'NULL',
#   'city': 'NULL',
#   'code': 'NULL',
#   'country_label': 'United States',
#   'country': 'http://dbpedia.org/resource/United_States',
#   'daylightSavingTimeZone_label': 'NULL',
#   'daylightSavingTimeZone': 'NULL',
#   'district_label': 'NULL',
#   'district': 'NULL',
#   'division_label': 'NULL',
#   'division': 'NULL',
#   'elevation': '{383.0|383.134}',
#   'federalState_label': 'NULL',
#   'federalState': 'NULL',
#   'foundingDate': '1878-06-14',
#   'foundingPerson_label': 'NULL',
#   'foundingPerson': 'NULL',
#   'foundingYear': 'NULL',
#   'governingBody_label': 'NULL',
#   'governingBody': 'NULL',
#   'government_label': 'NULL',
#   'government': 'NULL',
#   'governmentType_label': 'NULL',
#   'governmentType': 'NULL',
#   'isPartOf_label': '{Hancock County Iowa|Iowa|Winnebago County Iowa}',
#   'isPartOf': '{http://dbpedia.org/resource/Hancock_County,_Iowa|http://dbpedia.org/resource/Iowa|http://dbpedia.org/resource/Winnebago_County,_Iowa}',
#   'isoCodeRegion_label': 'NULL',
#   'isoCodeRegion': 'NULL',
#   'leader_label': 'NULL',
#   'leader': 'NULL',
#   'leaderName_label': 'NULL',
#   'leaderName': 'NULL',
#   'leaderParty_label': 'NULL',
#   'leaderParty': 'NULL',
#   'leaderTitle': 'NULL',
#   'location_label': 'NULL',
#   'location': 'NULL',
#   'maximumElevation': 'NULL',
#   'mayor_label': 'NULL',
#   'mayor': 'NULL',
#   'minimumElevation': 'NULL',
#   'motto': "{Friends are Closer|Where Nature's Close and}",
#   'municipality_label': 'NULL',
#   'municipality': 'NULL',
#   'part_label': 'NULL',
#   'part': 'NULL',
#   'percentageOfAreaWater': 'NULL',
#   'populationAsOf': 'NULL',
#   'populationDensity': '{345.4|345.407}',
#   'populationMetro': 'NULL',
#   'populationMetroDensity': 'NULL',
#   'populationRural': 'NULL',
#   'populationTotal': '4151',
#   'populationTotalRanking': 'NULL',
#   'populationUrban': 'NULL',
#   'populationUrbanDensity': 'NULL',
#   'postalCode': '50436',
#   'region_label': 'NULL',
#   'region': 'NULL',
#   'state_label': 'NULL',
#   'state': 'NULL',
#   'synonym': 'NULL',
#   'thumbnail_label': '200px-Hancock_County_Iowa_Incorporated_and_Unincorporated_areas_Forest_City_Highlighted.svg.png',
#   'thumbnail': 'http://upload.wikimedia.org/wikipedia/commons/thumb/7/75/Hancock_County_Iowa_Incorporated_and_Unincorporated_areas_Forest_City_Highlighted.svg/200px-Hancock_County_Iowa_Incorporated_and_Unincorporated_areas_Forest_City_Highlighted.svg.png',
#   'timeZone_label': 'Central Time Zone (North America)',
#   'timeZone': 'http://dbpedia.org/resource/Central_Time_Zone_(North_America)',
#   'twinCity_label': 'NULL',
#   'twinCity': 'NULL',
#   'twinCountry_label': 'NULL',
#   'twinCountry': 'NULL',
#   'type_label': 'City',
#   'type': 'http://dbpedia.org/resource/City',
#   'utcOffset': '{-5|-6}',
#   'point': '43.261944444444445 -93.64027777777778',
#   '22-rdf-syntax-ns#type_label': '{city|place|populated place|municipality|City|Place|_Feature|owl#Thing}',
#   '22-rdf-syntax-ns#type': '{http://dbpedia.org/ontology/City|http://dbpedia.org/ontology/Place|http://dbpedia.org/ontology/PopulatedPlace|http://dbpedia.org/ontology/Settlement|http://schema.org/City|http://schema.org/Place|http://www.opengis.net/gml/_Feature|http://www.w3.org/2002/07/owl#Thing}',
#   'wgs84_pos#lat': '43.2619',
#   'wgs84_pos#long': '-93.6403',
#   'depiction_label': 'Hancock_County_Iowa_Incorporated_and_Unincorporated_areas_Forest_City_Highlighted.svg',
#   'depiction': 'http://upload.wikimedia.org/wikipedia/commons/7/75/Hancock_County_Iowa_Incorporated_and_Unincorporated_areas_Forest_City_Highlighted.svg',
#   'homepage_label': 'NULL',
#   'homepage': 'NULL',
#   'name': 'Forest City Iowa',
#   'nick': 'NULL'}]

# %%
def checkType(filename):
    dataTypes = {}
