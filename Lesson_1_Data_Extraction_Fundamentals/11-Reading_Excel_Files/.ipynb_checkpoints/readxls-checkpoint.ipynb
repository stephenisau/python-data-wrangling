# %%
import xlrd
from zipfile import ZipFile
datafile = "2013_ERCOT_Hourly_Load_Data.xls"

"""
Your task is as follows:
- read the provided Excel file
- find and return the min and max values for the COAST region
- find and return the time value for the min and max entries
- the time values should be returned as Python tuples
"""

# %%
workbook = xlrd.open_workbook(datafile)
sheet = workbook.sheet_by_index(0)
sheet

# %%
sheet_data = [[sheet.cell_value(r, col) for col in range(sheet.ncols)] for r in range(sheet.nrows)]
sheet_data
# Out:
# [['Hour_End',
#   'COAST',
#   'EAST',
#   'FAR_WEST',
#   'NORTH',
#   'NORTH_C',
#   'SOUTHERN',
#   'SOUTH_C',
#   'WEST',
#   'ERCOT'],
#  [41275.041666666664,
#   7606.263544000012,
#   1073.892438,
#   1411.7505669999982,
#   784.9781659999992,
#   10369.094390000051,
#   2206.6750770000012,
#   4368.490945000006,
#   882.9319009999975,
#   28704.077028000065],
#  [41275.083333333336,
#   7388.082713999988,
#   1035.0219379999985,
#   1403.4722870000019,
#   776.3073870000006,
#   10152.35851800003,
#   2159.7332080000024,
#   4233.587967000001,
#   872.4047500000006,
#   28020.968769000025],
#  [41275.125,
#   7178.867877999996,
#   1036.0886969999988,
#   1395.053150000001,
#   768.1257480000011,
#   9988.051418000014,
#   2065.114705999998,
#   4082.8628599999975,
#   868.8539380000013,
#   27383.018395000006],
#  [41275.166666666664,
#   7038.822581000004,
#   1032.648840999999,
#   1395.5088200000002,
#   770.9379689999979,
#   9946.658654999992,
#   1990.9036990000016,
# ...

# %%
sheet_data[0][1]
# Out:
# 'COAST'

# %%
sheet.col_values(1, start_rowx=1, end_rowx=3)
# Out:
# [7606.263544000012, 7388.082713999988]

# %%
sheet.nrows
# Out:
# 7296

# %%
# RETURNS VALUES IN COAST COLUM IN AN ARRAY/LIST
# BOTH WORK
coast_values = [sheet_data[r][1] for r in range(1, sheet.nrows)]
#coast_values = sheet.col_values(1, start_rowx=1, end_rowx=sheet.nrows)
print(len(coast_values))
coast_values
# Out:
# 7295
# [7606.263544000012,
#  7388.082713999988,
#  7178.867877999996,
#  7038.822581000004,
#  6990.8579400000035,
#  7049.790188999973,
#  7176.995343999993,
#  7222.6800619999985,
#  7313.827285000014,
#  7676.26308800002,
#  8060.585862000017,
#  8392.872943000002,
#  8508.460275999982,
#  8497.619546999984,
#  8466.284440000005,
#  8430.930260999981,
#  8559.85737600002,
#  9094.197766000007,
#  9538.663746999995,
#  9561.898401999984,
#  9511.658059000018,
#  9330.179730999995,
#  8959.046718999998,
#  8504.496354999987,
#  8100.214418000016,
#  7936.352566999999,
#  7903.615991999997,
#  7979.405935000027,
#  8235.651255999981,
#  8842.35077499997,
#  9571.107773999987,
#  10047.547505999975,
#  10273.696688000009,
#  10568.515624000009,
#  10803.839959000012,
#  11009.537969999981,
#  11113.490216000051,
#  11170.191259999974,
#  11101.189911999978,
#  11088.88201699998,
#  11163.586184000047,
#  11672.348378000015,
#  11965.334782999993,
#  11806.204828,
# ...

# %%
max_value = max(coast_values)

coast_values.index(max_value)
# Out:
# 5391

# %%
header = [sheet.cell_value(0, col) for col in range(sheet.ncols)]
header
# Out:
# ['Hour_End',
#  'COAST',
#  'EAST',
#  'FAR_WEST',
#  'NORTH',
#  'NORTH_C',
#  'SOUTHERN',
#  'SOUTH_C',
#  'WEST',
#  'ERCOT']

# %%
sheet_data = [[sheet.cell_value(1, col) for col in range(sheet.ncols)] for r in range(sheet.nrows)]
sheet_data
# Out:
# [[41275.041666666664,
#   7606.263544000012,
#   1073.892438,
#   1411.7505669999982,
#   784.9781659999992,
#   10369.094390000051,
#   2206.6750770000012,
#   4368.490945000006,
#   882.9319009999975,
#   28704.077028000065],
#  [41275.041666666664,
#   7606.263544000012,
#   1073.892438,
#   1411.7505669999982,
#   784.9781659999992,
#   10369.094390000051,
#   2206.6750770000012,
#   4368.490945000006,
#   882.9319009999975,
#   28704.077028000065],
#  [41275.041666666664,
#   7606.263544000012,
#   1073.892438,
#   1411.7505669999982,
#   784.9781659999992,
#   10369.094390000051,
#   2206.6750770000012,
#   4368.490945000006,
#   882.9319009999975,
#   28704.077028000065],
#  [41275.041666666664,
#   7606.263544000012,
#   1073.892438,
#   1411.7505669999982,
#   784.9781659999992,
#   10369.094390000051,
#   2206.6750770000012,
#   4368.490945000006,
#   882.9319009999975,
#   28704.077028000065],
#  [41275.041666666664,
#   7606.263544000012,
#   1073.892438,
# ...

# %%
DATA = []
temp = {}

for value in sheet_data:
    DATA.append(dict(zip(header, value)))
print(DATA)
# Out:
# [{'Hour_End': 'Hour_End', 'COAST': 'COAST', 'EAST': 'EAST', 'FAR_WEST': 'FAR_WEST', 'NORTH': 'NORTH', 'NORTH_C': 'NORTH_C', 'SOUTHERN': 'SOUTHERN', 'SOUTH_C': 'SOUTH_C', 'WEST': 'WEST', 'ERCOT': 'ERCOT'}, {'Hour_End': 41275.041666666664, 'COAST': 7606.263544000012, 'EAST': 1073.892438, 'FAR_WEST': 1411.7505669999982, 'NORTH': 784.9781659999992, 'NORTH_C': 10369.094390000051, 'SOUTHERN': 2206.6750770000012, 'SOUTH_C': 4368.490945000006, 'WEST': 882.9319009999975, 'ERCOT': 28704.077028000065}, {'Hour_End': 41275.083333333336, 'COAST': 7388.082713999988, 'EAST': 1035.0219379999985, 'FAR_WEST': 1403.4722870000019, 'NORTH': 776.3073870000006, 'NORTH_C': 10152.35851800003, 'SOUTHERN': 2159.7332080000024, 'SOUTH_C': 4233.587967000001, 'WEST': 872.4047500000006, 'ERCOT': 28020.968769000025}, {'Hour_End': 41275.125, 'COAST': 7178.867877999996, 'EAST': 1036.0886969999988, 'FAR_WEST': 1395.053150000001, 'NORTH': 768.1257480000011, 'NORTH_C': 9988.051418000014, 'SOUTHERN': 2065.114705999998, 'SO
# ...

# %%
sheet.cell_value(0, 0)
# Out:
# 'Hour_End'

# %%
print ("\nDATES:")
print ("Type of data in cell (row 1, col 0):" )
print (sheet.cell_type(1, 0))
# Out:
# DATES:
# Type of data in cell (row 1, col 0):
# 3

# %%
print ("Get a slice of values in column 3, from rows 1-3:")
print (sheet.col_values(3, start_rowx=1, end_rowx=4))
# Out:
# Get a slice of values in column 3, from rows 1-3:
# [1411.7505669999982, 1403.4722870000019, 1395.053150000001]

# %%
exceltime = sheet.cell_value(1, 0)
print ("Time in Excel format:")
print (exceltime)
print ("Convert time to a Python datetime tuple, from the Excel float:")
print (xlrd.xldate_as_tuple(exceltime, 0))
# Out:
# Time in Excel format:
# 41275.041666666664
# Convert time to a Python datetime tuple, from the Excel float:
# (2013, 1, 1, 1, 0, 0)

# %%
    ### other useful methods:
print ("\nROWS, COLUMNS, and CELLS:")
print ("Number of rows in the sheet:")
print (sheet.nrows)

    # print "Value in cell (row 3, col 2):", 
    # print sheet.cell_value(3, 2)
    # print "Get a slice of values in column 3, from rows 1-3:"
    # print sheet.col_values(3, start_rowx=1, end_rowx=4)

    # print "\nDATES:"
    # print "Type of data in cell (row 1, col 0):", 
    # print sheet.cell_type(1, 0)
    # exceltime = sheet.cell_value(1, 0)
    # print "Time in Excel format:",
    # print exceltime
    # print "Convert time to a Python datetime tuple, from the Excel float:",
    # print xlrd.xldate_as_tuple(exceltime, 0)
# Out:
# ROWS, COLUMNS, and CELLS:
# Number of rows in the sheet:
# 7296

# %%
print("Type of data in cell (row 3, col 2):" )
print(sheet.cell_type(3, 2))
# Out:
# Type of data in cell (row 3, col 2):
# 2

# %%
#!/usr/bin/env python
"""
Your task is as follows:
- read the provided Excel file
- find and return the min and max values for the COAST region
- find and return the time value for the min and max entries
- the time values should be returned as Python tuples

Please see the test function for the expected return format
"""

import xlrd
from zipfile import ZipFile
datafile = "2013_ERCOT_Hourly_Load_Data.xls"

"""
def open_zip(datafile):
    with ZipFile('{0}.zip'.format(datafile), 'r') as myzip:
        myzip.extractall()
"""

def parse_file(datafile):
    workbook = xlrd.open_workbook(datafile)
    sheet = workbook.sheet_by_index(0)

    ### example on how you can get the data
    sheet_data = [[sheet.cell_value(r, col) for col in range(sheet.ncols)] for r in range(sheet.nrows)]
    
    data = {
            'maxtime': (0, 0, 0, 0, 0, 0),
            'maxvalue': 0,
            'mintime': (0, 0, 0, 0, 0, 0),
            'minvalue': 0,
            'avgcoast': 0
    }
    #Filter out coast values and excel times
    #coast_values = sheet.col_values(1, start_rowx=1, end_rowx=sheet.nrows)
    coast_values = [sheet_data[r][1] for r in range(1, sheet.nrows)]
    excel_values = [sheet_data[r][0] for r in range(1, sheet.nrows)]
    
    # Update dictionary values
    data['maxvalue'] = max(coast_values)
    data['minvalue'] = min(coast_values)
    
    
    max_value = coast_values.index(data['maxvalue']) + 1
    min_value = coast_values.index(data['minvalue']) + 1
    
    data['maxtime'] = xlrd.xldate_as_tuple(sheet_data[max_value][0], 0)
    data['mintime'] = xlrd.xldate_as_tuple(sheet_data[min_value][0], 0)
    
    data['avgcoast'] = sum(coast_values) / len(coast_values)
    
    return data


def test():
    data = parse_file(datafile)

    assert data['maxtime'] == (2013, 8, 13, 17, 0, 0)
    assert round(data['maxvalue'], 10) == round(18779.02551, 10)


test()

# %%
    ### other useful methods:
    # print "\nROWS, COLUMNS, and CELLS:"
    # print "Number of rows in the sheet:", 
    # print sheet.nrows
    # print "Type of data in cell (row 3, col 2):", 
    # print sheet.cell_type(3, 2)
    # print "Value in cell (row 3, col 2):", 
    # print sheet.cell_value(3, 2)
    # print "Get a slice of values in column 3, from rows 1-3:"
    # print sheet.col_values(3, start_rowx=1, end_rowx=4)

    # print "\nDATES:"
    # print "Type of data in cell (row 1, col 0):", 
    # print sheet.cell_type(1, 0)
    # exceltime = sheet.cell_value(1, 0)
    # print "Time in Excel format:",
    # print exceltime
    # print "Convert time to a Python datetime tuple, from the Excel float:",
    # print xlrd.xldate_as_tuple(exceltime, 0)
